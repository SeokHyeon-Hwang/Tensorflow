# %%
# Linear Regression
import tensorflow as tf

# %%
tf.set_random_seed(888)

# %%
x_tr = [1,2,3]
y_tr = [1,2,3]

# %%
W=tf.Variable(tf.random_normal([1]), name='weight')
b=tf.Variable(tf.random_normal([1]), name='bias')

# %%
# hypothsis Wx+b
hypothesis = x_tr*W+b

# %%
# cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - y_tr))

# %%
# minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train=optimizer.minimize(cost)

# %%
# Launch the graph in a session
sess = tf.Session()

# %%
# Initializes global variables in the graph
sess.run(tf.global_variables_initializer())

# %%
# Fit the line
for step in range(2001):
    sess.run(train)
    if step % 20 == 0:
        print(step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# 0 3.2182157 [0.05195266] [0.2777561]
# 20 0.0728927 [0.69005865] [0.52580684]
# 40 0.040362667 [0.7611423] [0.525958]
# 60 0.036423754 [0.7777493] [0.5036073]
# 80 0.033078525 [0.78870666] [0.48016497]
# 100 0.030042425 [0.7986855] [0.4576205]
# 120 0.027285015 [0.8081512] [0.4361161]
# 140 0.02478069 [0.81716776] [0.41562045]
# 160 0.02250621 [0.82576025] [0.3960878]
# 180 0.0204405 [0.83394885] [0.37747318]
# 200 0.01856441 [0.8417527] [0.35973337]
# 220 0.016860474 [0.84918976] [0.3428272]
# 240 0.015312965 [0.8562772] [0.32671556]
# 260 0.013907473 [0.8630317] [0.3113612]
# 280 0.0126309795 [0.86946875] [0.2967283]
# 300 0.01147167 [0.8756032] [0.28278315]
# 320 0.010418759 [0.8814494] [0.26949343]
# 340 0.009462484 [0.8870208] [0.25682825]
# 360 0.008593979 [0.8923304] [0.24475822]
# 380 0.007805185 [0.8973904] [0.23325549]
# 400 0.007088791 [0.90221274] [0.22229335]
# 420 0.0064381585 [0.90680844] [0.2118464]
# 440 0.0058472366 [0.91118807] [0.20189036]
# 460 0.0053105485 [0.91536194] [0.19240226]
# 480 0.0048231273 [0.9193396] [0.18336007]
# 500 0.004380441 [0.92313033] [0.17474283]
# 520 0.003978396 [0.9267429] [0.16653058]
# 540 0.0036132357 [0.93018574] [0.15870427]
# 560 0.0032816052 [0.9334667] [0.15124577]
# 580 0.0029804064 [0.93659353] [0.14413781]
# 600 0.0027068492 [0.93957347] [0.13736387]
# 620 0.0024584087 [0.9424132] [0.13090827]
# 640 0.0022327628 [0.94511956] [0.12475609]
# 660 0.0020278345 [0.9476988] [0.11889302]
# 680 0.001841707 [0.95015675] [0.11330551]
# 700 0.0016726743 [0.95249915] [0.10798056]
# 720 0.0015191458 [0.9547315] [0.10290586]
# 740 0.0013797156 [0.956859] [0.09806968]
# 760 0.0012530823 [0.9588863] [0.0934608]
# 780 0.0011380707 [0.96081865] [0.08906852]
# 800 0.0010336111 [0.96266] [0.08488263]
# 820 0.00093873893 [0.9644149] [0.08089344]
# 840 0.00085258094 [0.9660872] [0.07709174]
# 860 0.00077432394 [0.96768105] [0.07346871]
# 880 0.00070325757 [0.9691997] [0.07001597]
# 900 0.0006387098 [0.9706474] [0.0667255]
# 920 0.00058008457 [0.9720268] [0.06358963]
# 940 0.0005268413 [0.97334146] [0.06060115]
# 960 0.0004784864 [0.97459435] [0.05775311]
# 980 0.0004345685 [0.9757883] [0.05503891]
# 1000 0.000394681 [0.97692615] [0.05245229]
# 1020 0.0003584565 [0.9780105] [0.04998725]
# 1040 0.00032555978 [0.97904384] [0.04763804]
# 1060 0.00029567687 [0.9800287] [0.04539934]
# 1080 0.00026853805 [0.98096734] [0.04326574]
# 1100 0.00024389081 [0.9818618] [0.04123238]
# 1120 0.00022150547 [0.98271424] [0.03929457]
# 1140 0.00020117452 [0.98352665] [0.03744786]
# 1160 0.00018271156 [0.9843008] [0.03568796]
# 1180 0.00016594173 [0.98503864] [0.03401076]
# 1200 0.00015070965 [0.98574173] [0.03241237]
# 1220 0.00013687777 [0.9864118] [0.0308891]
# 1240 0.00012431401 [0.9870504] [0.02943745]
# 1260 0.00011290397 [0.987659] [0.028054]
# 1280 0.000102542166 [0.988239] [0.02673556]
# 1300 9.3130715e-05 [0.98879164] [0.02547909]
# 1320 8.458234e-05 [0.9893184] [0.0242817]
# 1340 7.681891e-05 [0.9898205] [0.02314054]
# 1360 6.976745e-05 [0.990299] [0.02205294]
# 1380 6.3363e-05 [0.9907549] [0.02101649]
# 1400 5.75475e-05 [0.99118936] [0.02002875]
# 1420 5.2265183e-05 [0.9916034] [0.01908746]
# 1440 4.7468595e-05 [0.991998] [0.01819042]
# 1460 4.3111417e-05 [0.99237406] [0.01733552]
# 1480 3.9154995e-05 [0.99273247] [0.01652082]
# 1500 3.5560308e-05 [0.993074] [0.01574441]
# 1520 3.229769e-05 [0.9933995] [0.0150045]
# 1540 2.9332492e-05 [0.99370974] [0.01429933]
# 1560 2.6639927e-05 [0.9940053] [0.0136273]
# 1580 2.4194638e-05 [0.9942871] [0.01298684]
# 1600 2.1973921e-05 [0.99455553] [0.01237652]
# 1620 1.9957599e-05 [0.99481136] [0.01179489]
# 1640 1.8125726e-05 [0.9950552] [0.01124063]
# 1660 1.646215e-05 [0.9952876] [0.01071236]
# 1680 1.4951562e-05 [0.9955091] [0.01020892]
# 1700 1.3579018e-05 [0.99572015] [0.00972912]
# 1720 1.2332949e-05 [0.9959213] [0.00927187]
# 1740 1.1200813e-05 [0.996113] [0.00883612]
# 1760 1.0172634e-05 [0.99629563] [0.00842086]
# 1780 9.239043e-06 [0.99646974] [0.00802512]
# 1800 8.390879e-06 [0.9966356] [0.00764798]
# 1820 7.620754e-06 [0.99679375] [0.00728858]
# 1840 6.9214766e-06 [0.9969444] [0.00694605]
# 1860 6.285983e-06 [0.997088] [0.00661962]
# 1880 5.7092852e-06 [0.9972248] [0.00630855]
# 1900 5.185144e-06 [0.9973553] [0.00601208]
# 1920 4.7093e-06 [0.99747956] [0.00572954]
# 1940 4.2771912e-06 [0.997598] [0.00546027]
# 1960 3.884344e-06 [0.99771094] [0.00520366]
# 1980 3.5279866e-06 [0.99781847] [0.0049591]
# 2000 3.2042572e-06 [0.997921] [0.00472604]
